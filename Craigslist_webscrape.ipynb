# %%
import requests

from bs4 import BeautifulSoup

URL = "https://lasvegas.craigslist.org/search/apa?hasPic=1&bundleDuplicates=1&max_price=1500&availabilityMode=0&housing_type=6&sale_date=all+dates"

page = requests.get(URL)
print(page.content)
soup = BeautifulSoup(page.content, "html.parser")
house_elements = results.find_all('li', class_="result-row")
print(house_elements)
results = soup.find(class_="rows")
print(results.prettify())
for house in house_elements: #this is the beginning of a for loop
    #print(house.text)
    price_element = house.find('span', class_='result-price') #this is finding the price of the house
    url_element = house.find('a', class_="result-image gallery")
    neighborhood_element = house.find('span', class_="result-hood")
    title_element = house.find('a', class_="result-title")
    
    
    print(title_element.text.strip()) #this is printing the title of the pose
    print(url_element['href']) #this is printing the 
    print(price_element.text.strip()) #this is printing the price of the house
    print() #this is performing a line brk
    
    print(neighborhood_element.text)
    
    #specific page parser

house_url = 'https://lasvegas.craigslist.org/apa/d/las-vegas-cozy-bedroom-bath-apartment/7430745771.html'
house_page = requests.get(house_url)
house_soup = BeautifulSoup(house_page.content, 'html.parser')
#print(house_page.content)
house_results = soup.find(class_="rows")
#print(results.prettify())

attributes = house_soup.find_all('p', class_="attrgroup")

for attribute in attributes:
   spans = attribute.find_all('span')
   for span in spans:
        text = span.text.strip()
        print(text)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    \n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1">\n\t<meta property="og:site_name" content="craigslist">\n\t<meta name="twitter:card" content="preview">\n\t<meta property="og:title" content="las vegas apartments / housing for rent - craigslist">\n\t<meta name="description" content="las vegas apartments / housing for rent - craigslist">\n\t<meta property="og:description" content="las vegas apartments / housing for rent - craigslist">\n\t<meta property="og:url" content="https://lasvegas.craigslist.org/d/apartments-housing-for-rent/search/apa">\n\t<title>las vegas apartments / housing for rent - craigslist</title>\n\t<link rel="canonical" href="https://lasvegas.craigslist.org/d/apartments-housing-for-rent/search/apa">\n\t<link rel="next" href="https://lasvegas.craigslist.org/d/apartments-housing-for-rent/search/apa?s=120&amp;availabilityMode=0&a
# ...

# %%
desc_element = house_soup.find('section',{"id":"postingbody"})
print(desc_element.text)
# Out:
# QR Code Link to This Post
#
#
# Brand New!!HOME* 3 bedroom 2 bathroom Available Now in Las Vegas, NV. If you interested please contact:: show contact info
# ...
